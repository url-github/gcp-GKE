# %% [markdown]
# [Kubernetes Engine: Qwik Start](https://www.cloudskillsboost.google/focuses/878?catalog_rank=%7B%22rank%22%3A11%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=23666130)

# %% [markdown]
# ![2023-05-05 14_19_17-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/kubernetes-engine/

# https://cloud.google.com/compute

# https://cloud.google.com/kubernetes-engine/docs/concepts/cluster-architecture

# https://kubernetes.io/

# %% [markdown]
# ![2023-05-05 14_25_57-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 15_21_59-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/compute/docs/load-balancing-and-autoscaling

# https://cloud.google.com/kubernetes-engine/docs/concepts/node-pools

# https://cloud.google.com/kubernetes-engine/docs/concepts/cluster-autoscaler

# https://cloud.google.com/kubernetes-engine/docs/how-to/node-auto-upgrades

# https://cloud.google.com/kubernetes-engine/docs/how-to/node-auto-repair

# https://cloud.google.com/stackdriver/docs/solutions/gke

# %% [markdown]
# ![2023-05-05 15_30_55-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/compute/docs/regions-zones/#available

# %%
gcloud config set compute/region us-west1

# %% [markdown]
# ![2023-05-05 15_44_04-Dashboard – qwiklabs-gcp-03-eb0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 15_44_51-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud config set compute/zone us-west1-a

# %% [markdown]
# ![2023-05-05 15_45_18-Dashboard – qwiklabs-gcp-03-eb0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 15_45_43-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/kubernetes-engine/docs/concepts/cluster-architecture

# https://cloud.google.com/compute/docs/instances/

# %%
gcloud container clusters create --machine-type=e2-medium --zone=us-west1-a lab-cluster

# %% [markdown]
# ![2023-05-05 15_54_31-Kubernetes clusters – Kubernetes Engine – qwiklabs-gcp-03-eb0… – Google Cloud co.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 15_48_59-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud container clusters get-credentials lab-cluster

# %% [markdown]
# ![2023-05-05 15_49_35-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 15_55_07-Kubernetes clusters – Kubernetes Engine – qwiklabs-gcp-03-eb0… – Google Cloud co.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 15_56_09-Kubernetes clusters – Kubernetes Engine – qwiklabs-gcp-03-eb0… – Google Cloud co.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 15_57_43-lab-cluster – Kubernetes Engine – qwiklabs-gcp-03-eb0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 15_58_15-lab-cluster – Kubernetes Engine – qwiklabs-gcp-03-eb0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 15_49_59-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://kubernetes.io/docs/concepts/workloads/controllers/deployment/

# https://kubernetes.io/docs/concepts/services-networking/service/

# https://kubernetes.io/docs/reference/generated/kubectl/kubectl-commands#create

# %%
kubectl create deployment hello-server --image=gcr.io/google-samples/hello-app:1.0

# %% [markdown]
# ![2023-05-05 15_53_40-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 15_58_55-lab-cluster – Kubernetes Engine – qwiklabs-gcp-03-eb0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 15_59_59-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/container-registry/docs

# %% [markdown]
# ![2023-05-05 16_01_52-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://kubernetes.io/docs/reference/generated/kubectl/kubectl-commands#expose

# %%
kubectl expose deployment hello-server --type=LoadBalancer --port 8080

# %% [markdown]
# ![2023-05-05 16_03_56-lab-cluster – Kubernetes Engine – qwiklabs-gcp-03-eb0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 16_04_19-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 16_04_57-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
kubectl get service

# %% [markdown]
# ![2023-05-05 16_07_01-lab-cluster – Kubernetes Engine – qwiklabs-gcp-03-eb0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 16_07_47-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# 35.197.39.132
# http://[EXTERNAL-IP]:8080

http://35.197.39.132:8080

# %% [markdown]
# ![2023-05-05 16_10_51-35.197.39.132_8080.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 16_11_25-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 16_11_56-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud container clusters delete lab-cluster

# %% [markdown]
# ![2023-05-05 16_12_24-lab-cluster – Kubernetes Engine – qwiklabs-gcp-03-eb0… – Google Cloud console.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/kubernetes-engine/docs/how-to/deleting-a-cluster

# %% [markdown]
# ![2023-05-05 16_13_12-Kubernetes Engine_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 16_14_38-lab-cluster – Kubernetes Engine – qwiklabs-gcp-03-eb0… – Google Cloud console.png](data:image/png;base64,...)
